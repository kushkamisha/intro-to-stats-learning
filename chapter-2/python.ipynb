# %% [markdown]
# ## College dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### (a)

# %%
college = pd.read_csv('data/College.csv')

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# ### (b)

# %%
college = pd.read_csv('data/College.csv', index_col=0)

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# ### (c) i

# %%
college.describe(include='all')
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### (c) ii

# %%
sns.set(font_scale=2)
sns.pairplot(college.iloc[:,:10],
             vars=['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc', 'F.Undergrad', 'P.Undergrad',
                   'Outstate', 'Room.Board'])

# %% [markdown]
# ### (c) iii

# %%
plt.scatter(college.Outstate, college.Private)
plt.xlabel('Outstate')
plt.ylabel('Private')
# Out:
# Text(0, 0.5, 'Private')

# %% [markdown]
# ### (c) iv

# %%
college['Elite'] = college.Top10perc > 50

# %%
college.describe(include='all')
# Out:
#        Private          Apps        Accept       Enroll   Top10perc  \
# count      777    777.000000    777.000000   777.000000  777.000000
# unique       2           NaN           NaN          NaN         NaN
# top        Yes           NaN           NaN          NaN         NaN
# freq       565           NaN           NaN          NaN         NaN
# mean       NaN   3001.638353   2018.804376   779.972973   27.558559
# std        NaN   3870.201484   2451.113971   929.176190   17.640364
# min        NaN     81.000000     72.000000    35.000000    1.000000
# 25%        NaN    776.000000    604.000000   242.000000   15.000000
# 50%        NaN   1558.000000   1110.000000   434.000000   23.000000
# 75%        NaN   3624.000000   2424.000000   902.000000   35.000000
# max        NaN  48094.000000  26330.000000  6392.000000   96.000000
#
#          Top25perc   F.Undergrad   P.Undergrad      Outstate   Room.Board  \
# count   777.000000    777.000000    777.000000    777.000000   777.000000
# ...

# %%
plt.scatter(college.Outstate, college.Elite)
plt.xlabel('Outstate')
plt.ylabel('Elite')
# Out:
# Text(0, 0.5, 'Elite')

# %% [markdown]
# ### (c) vi

# %%
college.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate', 'Elite'],
#       dtype='object')

# %%
parameters = {'axes.labelsize': 20,
          'axes.titlesize': 24}
plt.rcParams.update(parameters)


fig, ((a1, a2), (a3, a4)) = plt.subplots(2, 2, figsize=(12,12))

a1.hist(college.Enroll, color='r')
a1.set_title('Histogram of Enrollment')
a1.set_xlabel('Num of new students enrolled')

a2.hist(college['F.Undergrad'], bins=15, color='g')
a2.set_title('Histogram of Full-time Undergrads')
a2.set_xlabel('Num of full-time undergrads')

a3.hist(college['Grad.Rate'], bins=7, color='b')
a3.set_title('Histogram of Graduation Rate')
a3.set_xlabel('Graduation rate (%)')
a3.set_xticks([*range(0, 121, 20)])

a4.hist(college.PhD, color='c')
a4.set_title('Histogram of Percent of faculty\n with Ph.D.’s')
a4.set_xlabel('PhD (%)')
a4.set_xticks([*range(0, 101, 20)])

fig.tight_layout()

# %% [markdown]
# ### (c) v

# %% [markdown]
# If an institution is in the top 10% of all, then it's for sure in the top 25% but not vice versa

# %%
plt.scatter(college.Top10perc, college.Top25perc)
plt.xlabel('Top 10%')
plt.ylabel('Top 25%')
# Out:
# Text(0, 0.5, 'Top 25%')

# %% [markdown]
# ## Auto dataset

# %% [markdown]
# ### Preprocessing

# %%
Auto = pd.read_csv('data/Auto.data', sep='\s+')

# %%
Auto = Auto.replace(['?'], [None])
Auto = Auto.dropna()

types = {
    'mpg': 'float',
    'cylinders': 'float',
    'displacement': 'float',
    'horsepower': 'float',
    'weight': 'float',
    'acceleration': 'float',
    'year': 'float',
    'origin': 'float',
    'name': 'string'
}
Auto = Auto.astype(types)

# %%
Auto.describe(include='all')
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   392.000000  392.000000    392.000000  392.000000   392.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.445918    5.471939    194.411990  104.469388  2977.584184
# std       7.805007    1.705783    104.644004   38.491160   849.402560
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%      22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%      29.000000    8.000000    275.750000  126.000000  3614.750000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration        year      origin         name
# count     392.000000  392.000000  392.000000          392
# ...

# %%
Auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0        8.0         307.0       130.0  3504.0          12.0  70.0
# 1  15.0        8.0         350.0       165.0  3693.0          11.5  70.0
# 2  18.0        8.0         318.0       150.0  3436.0          11.0  70.0
# 3  16.0        8.0         304.0       150.0  3433.0          12.0  70.0
# 4  17.0        8.0         302.0       140.0  3449.0          10.5  70.0
#
#    origin                       name
# 0     1.0  chevrolet chevelle malibu
# 1     1.0          buick skylark 320
# 2     1.0         plymouth satellite
# 3     1.0              amc rebel sst
# 4     1.0                ford torino

# %%
Auto.shape
# Out:
# (392, 9)

# %% [markdown]
# ### (a)

# %% [markdown]
# |Col Name|Quantitative|Qualitative|
# |---|---|---|
# |mpg|x||
# |cylinders||x|
# |displacement|x||
# |horsepower|x||
# |weight|x||
# |acceleration|x||
# |year|x||
# |origin||x|
# |name||x|

# %% [markdown]
# ### (b)

# %%
sapply(
    Auto[c('mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year')],
    range)
# Out:
#      mpg  displacement horsepower weight acceleration year
# [1,]  9.0  68           46        1613    8.0         70
# [2,] 46.6 455          230        5140   24.8         82

# %% [markdown]
# ### (c)

# %%
sapply(
    Auto[c('mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year')], 
    (function (x) list(mean(x),sd(x))))
# Out:
#      mpg      displacement horsepower weight   acceleration year
# [1,] 23.44592 194.412      104.4694   2977.584 15.54133     75.97959
# [2,] 7.805007 104.644      38.49116   849.4026 2.758864     3.683737

# %% [markdown]
# ### (d)

# %%
Auto_reduced = Auto[-c(10:85),]

# %%
sapply(
    Auto_reduced[c('mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year')], 
    (function (x) list(range(x), mean(x),sd(x))))
# Out:
#      mpg        displacement horsepower weight     acceleration year
# [1,] 11.0, 46.6 68, 455      46, 230    1649, 4997 8.5, 24.8    70, 82
# [2,] 24.40443   187.2405     100.7215   2935.972   15.7269      77.14557
# [3,] 7.867283   99.67837     35.70885   811.3002   2.693721     3.106217

# %% [markdown]
# ### (e)

# %%
options(repr.plot.width=7, repr.plot.height=7)
pairs(Auto)
options(repr.plot.width=4, repr.plot.height=4)
# Out:
# plot without title

# %% [markdown]
# There is a strong correlation between car horsepower and weight. This is presumably because more power means a heavier motor

# %%
plot(Auto$horsepower, Auto$weight)
# Out:
# plot without title

# %% [markdown]
# Some correlation (not extremely strong though) is between the number of cylinders in a car motor and the time for acceleration. Generally, more cylinders -> more powerful motor -> less time to accelerate a car

# %%
plot(Auto$acceleration, Auto$cylinders)
# Out:
# plot without title

# %% [markdown]
# ### (f)

# %%
names(Auto)
# Out:
# [1] "mpg"          "cylinders"    "displacement" "horsepower"   "weight"
# [6] "acceleration" "year"         "origin"       "name"

# %%
par(mfrow=c(3,3))
options(repr.plot.width=7, repr.plot.height=7)

plot(Auto$cylinders, Auto$mpg)
plot(Auto$displacement, Auto$mpg)
plot(Auto$horsepower, Auto$mpg)
plot(Auto$weight, Auto$mpg)

plot(Auto$acceleration, Auto$mpg)
plot(Auto$year, Auto$mpg)
plot(Auto$origin, Auto$mpg)
plot(Auto$mpg, Auto$name)
# Out:
# plot without title

# %% [markdown]
# As you may notice there is a correlation with many factors
#
# |Factor|Correlation|Probable reason|
# |------|-------------|---------------|
# |Number of cylinders|negative|More cylinders mean more powerful motor thus its gas consumption is higher|
# |Displacement|negative|Bigger engine displacement -> more powerful motor -> higher gas consumption|
# |Horsepower|negative|Bigger engine horsepower -> more powerful motor -> higher gas consumption|
# |Weight|negative|Bigger car weight -> (probably) bigger engine weight -> more powerful motor -> higher gas consumption|
# |Acceleration|slightly positive|Not a strong correlation. Maybe newer cars have more powerful motors with faster acceleration, but due to technical development these engines are more economical|
# |Year|generally positive|Newer car -> newer engine -> more economical engine -> lesser gas consumption|
# |Origin|no correlation|It may seem that there is a slight positive correlation, but it's simply luck. We can reassign new numbers to the same origins and have a completely different tendency|
# |Name|no correlation|No wonder why. Would be strange if the name of the car affected its gas consumption|

# %% [markdown]
# ## Boston dataset

# %% [markdown]
# ### (a)

# %%
install.packages('MASS')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library('MASS')

# %%
head(Boston)
# Out:
#   crim    zn indus chas nox   rm    age  dis    rad tax ptratio black  lstat
# 1 0.00632 18 2.31  0    0.538 6.575 65.2 4.0900 1   296 15.3    396.90 4.98
# 2 0.02731  0 7.07  0    0.469 6.421 78.9 4.9671 2   242 17.8    396.90 9.14
# 3 0.02729  0 7.07  0    0.469 7.185 61.1 4.9671 2   242 17.8    392.83 4.03
# 4 0.03237  0 2.18  0    0.458 6.998 45.8 6.0622 3   222 18.7    394.63 2.94
# 5 0.06905  0 2.18  0    0.458 7.147 54.2 6.0622 3   222 18.7    396.90 5.33
# 6 0.02985  0 2.18  0    0.458 6.430 58.7 6.0622 3   222 18.7    394.12 5.21
#   medv
# 1 24.0
# 2 21.6
# 3 34.7
# 4 33.4
# 5 36.2
# 6 28.7

# %%
dim(Boston)
# Out:
# [1] 506  14

# %%
# ?Boston

# %% [markdown]
# ### (b)

# %%
options(repr.plot.width=8, repr.plot.height=8)
pairs(Boston, cex=.3)
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=5)
plot(Boston$zn, Boston$nox,
     xlab='Proportion of residential land zoned for lots over 25,000 sq.ft',
     ylab='Nitrogen oxides concentration (parts per 10 million)',
     main='Less green zones cause more air pollution and vise versa')
# Out:
# Plot with title “Less green zones cause more air pollution and vise versa”

# %%
options(repr.plot.width=7, repr.plot.height=5)
plot(Boston$age, Boston$crim,
     xlab='Per capita crime rate by town',
     ylab='Proportion of owner-occupied units built prior to 1940',
     main='Older units means bigger crime rate')
# Out:
# Plot with title “Older units means bigger crime rate”

# %% [markdown]
# ### (c)

# %% [markdown]
# As you may spot from the last scatter plot, there is a certain correlation between the age of occupied units and a crime rate. It seems that if everyone leaves in new apartments (means that they have enough money to afford it) - the overall crime rate is lesser in that town.

# %% [markdown]
# ### (d)

# %% [markdown]
# Top 5 towns with highest criminal rate

# %%
Boston[order(-Boston$crim)[1:5],]
# Out:
#     crim    zn indus chas nox   rm    age   dis    rad tax ptratio black  lstat
# 381 88.9762 0  18.1  0    0.671 6.968  91.9 1.4165 24  666 20.2    396.90 17.21
# 419 73.5341 0  18.1  0    0.679 5.957 100.0 1.8026 24  666 20.2     16.45 20.62
# 406 67.9208 0  18.1  0    0.693 5.683 100.0 1.4254 24  666 20.2    384.97 22.98
# 411 51.1358 0  18.1  0    0.597 5.757 100.0 1.4130 24  666 20.2      2.60 10.11
# 415 45.7461 0  18.1  0    0.693 4.519 100.0 1.6582 24  666 20.2     88.27 36.98
#     medv
# 381 10.4
# 419  8.8
# 406  5.0
# 411 15.0
# 415  7.0

# %% [markdown]
# Their average criminal rate is 65%!

# %%
mean(Boston[order(-Boston$crim)[1:5],1])
# Out:
# [1] 65.4626

# %% [markdown]
# Top 15 towns with highest taxes

# %%
Boston[order(-Boston$tax)[1:15],]
# Out:
#     crim    zn indus chas nox   rm    age  dis    rad tax ptratio black  lstat
# 489 0.15086 0  27.74 0    0.609 5.454 92.7 1.8209  4  711 20.1    395.09 18.06
# 490 0.18337 0  27.74 0    0.609 5.414 98.3 1.7554  4  711 20.1    344.05 23.97
# 491 0.20746 0  27.74 0    0.609 5.093 98.0 1.8226  4  711 20.1    318.43 29.68
# 492 0.10574 0  27.74 0    0.609 5.983 98.8 1.8681  4  711 20.1    390.11 18.07
# 493 0.11132 0  27.74 0    0.609 5.983 83.5 2.1099  4  711 20.1    396.90 13.35
# 357 8.98296 0  18.10 1    0.770 6.212 97.4 2.1222 24  666 20.2    377.73 17.60
# 358 3.84970 0  18.10 1    0.770 6.395 91.0 2.5052 24  666 20.2    391.34 13.27
# 359 5.20177 0  18.10 1    0.770 6.127 83.4 2.7227 24  666 20.2    395.43 11.48
# 360 4.26131 0  18.10 0    0.770 6.112 81.3 2.5091 24  666 20.2    390.74 12.67
# 361 4.54192 0  18.10 0    0.770 6.398 88.0 2.5182 24  666 20.2    374.56  7.79
# 362 3.83684 0  18.10 0    0.770 6.251 91.1 2.2955 24  666 20.2    350.65 14.19
# ...

# %% [markdown]
# All top 15 towns with highest taxes simply have high taxes. Nothing to say more here

# %%
summary(Boston[,c('tax')])
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   187.0   279.0   330.0   408.2   666.0   711.0

# %% [markdown]
# Top 15 towns with highest pupil/teacher ratio

# %%
Boston[order(-Boston$ptratio)[1:15],]
# Out:
#     crim    zn indus chas nox   rm    age  dis     rad tax ptratio black  lstat
# 355 0.04301 80  1.91 0    0.413 5.663 21.9 10.5857 4   334 22.0    382.80  8.05
# 356 0.10659 80  1.91 0    0.413 5.936 19.5 10.5857 4   334 22.0    376.04  5.57
# 128 0.25915  0 21.89 0    0.624 5.693 96.0  1.7883 4   437 21.2    392.11 17.19
# 129 0.32543  0 21.89 0    0.624 6.431 98.8  1.8125 4   437 21.2    396.90 15.39
# 130 0.88125  0 21.89 0    0.624 5.637 94.7  1.9799 4   437 21.2    396.90 18.34
# 131 0.34006  0 21.89 0    0.624 6.458 98.9  2.1185 4   437 21.2    395.04 12.60
# 132 1.19294  0 21.89 0    0.624 6.326 97.7  2.2710 4   437 21.2    396.90 12.26
# 133 0.59005  0 21.89 0    0.624 6.372 97.9  2.3274 4   437 21.2    385.76 11.12
# 134 0.32982  0 21.89 0    0.624 5.822 95.4  2.4699 4   437 21.2    388.69 15.03
# 135 0.97617  0 21.89 0    0.624 5.757 98.4  2.3460 4   437 21.2    262.76 17.31
# 136 0.55778  0 21.89 0    0.624 6.335 98.2  2.1107 4   437 21.2    394.67 16.96
# ...

# %% [markdown]
# The maximum value is close to the median thus it's not really distinct for to 15 towns from others

# %%
summary(Boston[,c('ptratio')])
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12.60   17.40   19.05   18.46   20.20   22.00

# %% [markdown]
# ### (e)

# %%
length(Boston[Boston$chas==1,])
# Out:
# [1] 14

# %% [markdown]
# ### (f)

# %%
median(Boston[,c('ptratio')])
# Out:
# [1] 19.05

# %% [markdown]
# ### (g)

# %% [markdown]
# There are 2 suburbs that have the lowest median value of owner-occupied homes

# %%
Boston[Boston$medv==min(Boston$medv),]
# Out:
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio black  lstat
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    396.90 30.59
# 406 67.9208 0  18.1  0    0.693 5.683 100 1.4254 24  666 20.2    384.97 22.98
#     medv
# 399 5
# 406 5

# %% [markdown]
# ### (h)

# %%
dim(Boston[Boston$rm>7,])[1]
dim(Boston[Boston$rm>8,])[1]
# Out:
# [1] 64
# [1] 13

# %%
Boston[Boston$rm>8,]
# Out:
#     crim    zn indus chas nox    rm    age  dis    rad tax ptratio black  lstat
# 98  0.12083  0  2.89 0    0.4450 8.069 76.0 3.4952  2  276 18.0    396.90 4.21
# 164 1.51902  0 19.58 1    0.6050 8.375 93.9 2.1620  5  403 14.7    388.45 3.32
# 205 0.02009 95  2.68 0    0.4161 8.034 31.9 5.1180  4  224 14.7    390.55 2.88
# 225 0.31533  0  6.20 0    0.5040 8.266 78.3 2.8944  8  307 17.4    385.05 4.14
# 226 0.52693  0  6.20 0    0.5040 8.725 83.0 2.8944  8  307 17.4    382.00 4.63
# 227 0.38214  0  6.20 0    0.5040 8.040 86.5 3.2157  8  307 17.4    387.38 3.13
# 233 0.57529  0  6.20 0    0.5070 8.337 73.3 3.8384  8  307 17.4    385.91 2.47
# 234 0.33147  0  6.20 0    0.5070 8.247 70.4 3.6519  8  307 17.4    378.95 3.95
# 254 0.36894 22  5.86 0    0.4310 8.259  8.4 8.9067  7  330 19.1    396.90 3.54
# 258 0.61154 20  3.97 0    0.6470 8.704 86.9 1.8010  5  264 13.0    389.70 5.12
# 263 0.52014 20  3.97 0    0.6470 8.398 91.5 2.2885  5  264 13.0    386.86 5.91
# ...

# %%
summary(Boston[Boston$rm>8,])
summary(Boston)
# Out:
#       crim               zn            indus             chas
#  Min.   :0.02009   Min.   : 0.00   Min.   : 2.680   Min.   :0.0000
#  1st Qu.:0.33147   1st Qu.: 0.00   1st Qu.: 3.970   1st Qu.:0.0000
#  Median :0.52014   Median : 0.00   Median : 6.200   Median :0.0000
#  Mean   :0.71879   Mean   :13.62   Mean   : 7.078   Mean   :0.1538
#  3rd Qu.:0.57834   3rd Qu.:20.00   3rd Qu.: 6.200   3rd Qu.:0.0000
#  Max.   :3.47428   Max.   :95.00   Max.   :19.580   Max.   :1.0000
#       nox               rm             age             dis
#  Min.   :0.4161   Min.   :8.034   Min.   : 8.40   Min.   :1.801
#  1st Qu.:0.5040   1st Qu.:8.247   1st Qu.:70.40   1st Qu.:2.288
#  Median :0.5070   Median :8.297   Median :78.30   Median :2.894
#  Mean   :0.5392   Mean   :8.349   Mean   :71.54   Mean   :3.430
#  3rd Qu.:0.6050   3rd Qu.:8.398   3rd Qu.:86.50   3rd Qu.:3.652
#  Max.   :0.7180   Max.   :8.780   Max.   :93.90   Max.   :8.907
#       rad              tax           ptratio          black
# ...

# %% [markdown]
# For suburbs where average more than 8 rooms per dwelling compared to all dataset:
# - median "lower status of the population (percent)" is much lower
# - median "per capita crime rate by town" is much lower
# - median "median value of owner-occupied homes in $1000s" is twice as big
